# %%
from multimodules_constructors import *
from box_tensor_product import *

# %%
M = SolidPairOfPants(2,4,4)
M.show(format_type='idempotent')
# Out:
# Generators (32, overlap False)
# ∅| 1| 1 2 3 4	 [∅, (1), (1 2 3 4)]
# ∅| 1 2| 1 2 4	 [∅, (1 2), (1 2 4)]
# ∅| 1 3| 1 3 4	 [∅, (1 3), (1 3 4)]
# ∅| 1 2 3| 1 4	 [∅, (1 2 3), (1 4)]
# ∅| 1 4| 2 3 4	 [∅, (1 4), (2 3 4)]
# ∅| 1 2 4| 2 4	 [∅, (1 2 4), (2 4)]
# ∅| 1 3 4| 3 4	 [∅, (1 3 4), (3 4)]
# ∅| 1 2 3 4| 4	 [∅, (1 2 3 4), (4)]
# 1| 1| 1 2 3	 [(1), (1), (1 2 3)]
# 1| 1 2| 1 2	 [(1), (1 2), (1 2)]
# 1| 1 3| 1 3	 [(1), (1 3), (1 3)]
# 1| 1 2 3| 1	 [(1), (1 2 3), (1)]
# 1| 1 4| 2 3	 [(1), (1 4), (2 3)]
# 1| 1 2 4| 2	 [(1), (1 2 4), (2)]
# 1| 1 3 4| 3	 [(1), (1 3 4), (3)]
# 1| 1 2 3 4| ∅	 [(1), (1 2 3 4), ∅]
# 2| ∅| 1 2 3 4	 [(2), ∅, (1 2 3 4)]
# 2| 2| 1 2 4	 [(2), (2), (1 2 4)]
# 2| 3| 1 3 4	 [(2), (3), (1 3 4)]
# 2| 2 3| 1 4	 [(2), (2 3), (1 4)]
# 2| 4| 2 3 4	 [(2), (4), (2 3 4)]
# 2| 2 4| 2 4	 [(2), (2 4), (2 4)]
# 2| 3 4| 3 4	 [(2), (3 4), (3 4)]
# 2| 2 3 4| 4	 [(2), (2 3 4), (4)]
# 1 2| ∅| 1 2 3	 [(1 2), ∅, (1 2 3)]
# 1 2| 2| 1 2	 [(1 2), (2), (1 2)]
# 1 2| 3| 1 3	 [(1 2), (3), (1 3)]
# ...

# %%
M.generators

# %%
M.arrows

# %%
import basics

# %%
basics.crop(2,0,1)
